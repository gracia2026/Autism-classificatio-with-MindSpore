# %%
# !pip install mindspore
# Out:
# Requirement already satisfied: mindspore in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (2.7.1.post1)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (1.26.4)
# Requirement already satisfied: protobuf>=3.13.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (6.33.2)
# Requirement already satisfied: asttokens>=2.0.4 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (3.0.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (12.1.0)
# Requirement already satisfied: scipy>=1.5.4 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (1.16.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (25.0)
# Requirement already satisfied: psutil>=5.6.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (7.0.0)
# Requirement already satisfied: astunparse>=1.6.3 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (1.6.3)
# Requirement already satisfied: safetensors>=0.4.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (0.7.0)
# Requirement already satisfied: dill>=0.3.7 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from astunparse>=1.6.3->mindspore) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from astunparse>=1.6.3->mindspore) (1.17.0)

# %%
import mindspore
print(mindspore.__version__)
# Out:
# 2.7.1.post1

# %%
import pandas as pd
import numpy as np
import mindspore as ms
from mindspore import nn, ops, Tensor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
pip install mindcv
# Out:
# Requirement already satisfied: mindcv in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindcv) (1.26.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindcv) (6.0.3)
# Requirement already satisfied: tqdm in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindcv) (4.67.1)
# Requirement already satisfied: colorama in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from tqdm->mindcv) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mindcv

# %%
import mindcv
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
import mindspore.dataset as ds
from mindspore.dataset import vision

# %%
pip install mindspore mindcv scikit-learn pillow numpy
# Out:
# Requirement already satisfied: mindspore in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (2.7.1.post1)
# Requirement already satisfied: mindcv in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (0.3.0)
# Requirement already satisfied: scikit-learn in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (1.8.0)
# Requirement already satisfied: pillow in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (12.1.0)
# Requirement already satisfied: numpy in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (1.26.4)
# Requirement already satisfied: protobuf>=3.13.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (6.33.2)
# Requirement already satisfied: asttokens>=2.0.4 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (3.0.0)
# Requirement already satisfied: scipy>=1.5.4 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (1.16.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (25.0)
# Requirement already satisfied: psutil>=5.6.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (7.0.0)
# Requirement already satisfied: astunparse>=1.6.3 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (1.6.3)
# Requirement already satisfied: safetensors>=0.4.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (0.7.0)
# Requirement already satisfied: dill>=0.3.7 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindspore) (0.4.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindcv) (6.0.3)
# Requirement already satisfied: tqdm in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from mindcv) (4.67.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from astunparse>=1.6.3->mindspore) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from astunparse>=1.6.3->mindspore) (1.17.0)
# Requirement already satisfied: colorama in c:\users\welcome\miniconda3\envs\jupyter_env\lib\site-packages (from tqdm->mindcv) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import shutil
import numpy as np
from PIL import Image

import mindspore as ms
from mindspore import nn, Tensor

from mindcv import create_model

import mindspore.dataset.vision as vision
import mindspore.dataset.transforms as transforms

from sklearn.cluster import KMeans

# %%
from mindspore.dataset import ImageFolderDataset, vision
from mindcv.models import resnet18

# %%
import matplotlib.pyplot as plt
from PIL import Image
from collections import defaultdict
